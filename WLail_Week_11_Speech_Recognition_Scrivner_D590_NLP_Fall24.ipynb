# %% [markdown]
# <a href="https://colab.research.google.com/github/wlail-iu/D590-NLP-F24/blob/main/WLail_Week_11_Speech_Recognition_Scrivner_D590_NLP_Fall24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Visualizing Speech Recognition

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from scipy.io.wavfile import write

# %%
# Read the audio file
# unzip the speech_data.zip folder, within that, you'll find all required audio and JSON files
sampling_freq, signal = wavfile.read('/content/spoken_word.wav')

# %%
# Display the params
print('\nSignal shape:', signal.shape)
print('Datatype:', signal.dtype)
print('Signal duration:', round(signal.shape[0] / float(sampling_freq), 2), 'seconds')
# Out:
# Signal shape: (3251,)
# Datatype: int16
# Signal duration: 0.41 seconds

# %%
# Normalize the signal
signal = signal / np.power(2, 15)

# %%
# Extract the first 50 values
signal = signal[:50]

# %%
# Construct the time axis in milliseconds
time_axis = 1000 * np.arange(0, len(signal), 1) / float(sampling_freq)

# %%
# Plot the audio signal
plt.plot(time_axis, signal, color='black')
plt.xlabel('Time (milliseconds)')
plt.ylabel('Amplitude')
plt.title('Input audio signal')
plt.show()

# %% [markdown]
# ## Transforming audio signals to the frequency domain

# %%
# Extract the length of the audio signal
len_signal = len(signal)

# Extract the half length
len_half = np.ceil((len_signal + 1) / 2.0).astype(int)

# %%
# Apply Fourier transform
freq_signal = np.fft.fft(signal)

# %%
# Normalization
freq_signal = abs(freq_signal[0:len_half]) / len_signal

# Take the square
freq_signal **= 2

# %%
# Extract the length of the frequency transformed signal
len_fts = len(freq_signal)

# Adjust the signal for even and odd cases
if len_signal % 2:
  freq_signal[1:len_fts] *= 2

else:
  freq_signal[1:len_fts-1] *= 2

# %%
# Extract the power value in dB
signal_power = 10 * np.log10(freq_signal)

# %%
# Build the X axis
x_axis = np.arange(0, len_half, 1) * (sampling_freq / len_signal) / 1000.0

# %%
# Plot the figure
plt.figure()
plt.plot(x_axis, signal_power, color='black')
plt.xlabel('Frequency (kHz)')
plt.ylabel('Signal power (dB)')
plt.show()

# %% [markdown]
# ## Generating audio signals

# %%
# Output file where the audio will be saved
output_file = '/content/generated_audio.wav'

# %%
# Specify audio parameters
duration = 4 # in seconds
sampling_freq = 44100 # in Hz
tone_freq = 784
min_val = -4 * np.pi
max_val = 4 * np.pi

# %%
# Generate the audio signal
t = np.linspace(min_val, max_val, duration * sampling_freq)
signal = np.sin(2 * np.pi * tone_freq * t)

# %%
# Add some noise to the signal
noise = 0.5 * np.random.rand(duration * sampling_freq)
signal += noise

# %%
# Scale it to 16-bit integer values
scaling_factor = np.power(2, 15) - 1
signal_normalized = signal / np.max(np.abs(signal))
signal_scaled = np.int16(signal_normalized * scaling_factor)

# %%
# Save the audio signal in the output file
write(output_file, sampling_freq, signal_scaled)

# %%
# Extract the first 200 values from the audio signal
signal = signal[:200]

# %%
# Construct the time axis in milliseconds
time_axis = 1000 * np.arange(0, len(signal), 1) / float(sampling_freq)

# %%
# Plot the audio signal
plt.plot(time_axis, signal, color='black')
plt.xlabel('Time (milliseconds)')
plt.ylabel('Amplitude')
plt.title('Generated audio signal')
plt.show()

# %% [markdown]
# ## Synthesizing tones to generate music

# %% [markdown]
# In order to see the frequency mapping for these standard tones, check out this link:<br> http://www.phy.mtu.edu/~suits/notefre-qs.html.

# %%
# Synthesize the tone based on the input parameters
def tone_synthesizer(freq, duration, amplitude=1.0, sampling_freq=44100):
  # Construct the time axis
  time_axis = np.linspace(int(0), int(duration), int(duration) * int(sampling_freq))

  # Construct the audio signal
  signal = amplitude * np.sin(2 * np.pi * freq * time_axis)
  return signal.astype(np.int16)

if __name__=='__main__':
  # Names of output files
  file_tone_single = 'generated_tone_single.wav'
  file_tone_sequence = 'generated_tone_sequence.wav'

# %%
# Source: http://www.phy.mtu.edu/~suits/notefreqs.html
mapping_file = '/content/tone_mapping.json'

# Load the tone to frequency map from the mapping file
with open(mapping_file, 'r') as f:
  tone_map = json.loads(f.read())

# %%
# Set input parameters to generate 'F' tone
tone_name = 'F'
# seconds
duration = 3
# amplitude
amplitude = 12000
# Hz
sampling_freq = 44100

# %%
# Extract the tone frequency
tone_freq = tone_map[tone_name]

# %%
# Generate the tone using the above parameters
synthesized_tone = tone_synthesizer(tone_freq, duration, amplitude, sampling_freq)

# %%
# Write the audio signal to the output file
write(file_tone_single, sampling_freq, synthesized_tone)

# %%
# Define the tone sequence along with corresponding
# durations in seconds
tone_sequence = [('G', 0.4), ('D', 0.5), ('F', 0.3), ('C', 0.6), ('A', 0.4)]

# %%
# Construct the audio signal based on the above sequence
signal = np.array([])
for item in tone_sequence:
  # Get the name of the tone
  tone_name = item[0]

  # Extract the corresponding frequency of the tone
  freq = tone_map[tone_name]

  # Extract the duration
  duration = item[1]

  # Synthesize the tone
  synthesized_tone = tone_synthesizer(freq, duration, amplitude, sampling_freq)

  # Append the output signal
  signal = np.append(signal, synthesized_tone, axis=0)

# Save the audio in the output file
write(file_tone_sequence, sampling_freq, signal)

# %% [markdown]
# ## Extracting speech features

# %%
# !pip install python_speech_features
# Out:
# Collecting python_speech_features
#   Downloading python_speech_features-0.6.tar.gz (5.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: python_speech_features
#   Building wheel for python_speech_features (setup.py) ... done
#   Created wheel for python_speech_features: filename=python_speech_features-0.6-py3-none-any.whl size=5868 sha256=cc3c0e8f631f280a4fcab865a3c6a9f2fc2bb0ed894035ca64dc68eba7630107
#   Stored in directory: /root/.cache/pip/wheels/5a/9e/68/30bad9462b3926c29e315df16b562216d12bdc215f4d240294
# Successfully built python_speech_features
# Installing collected packages: python_speech_features
# Successfully installed python_speech_features-0.6

# %%
#!pip install python_speech_features
from python_speech_features import mfcc, logfbank

# %%
# Read the input audio file
sampling_freq, signal = wavfile.read('/content/random_sound.wav')

# Take the first 10,000 samples for analysis
signal = signal[:10000]

# %%
# Extract the MFCC features
features_mfcc = mfcc(signal, sampling_freq)

# Print the parameters for MFCC
print('\nMFCC:\nNumber of windows =', features_mfcc.shape[0])
print('Length of each feature =', features_mfcc.shape[1])
# Out:
# WARNING:root:frame length (1103) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# MFCC:
# Number of windows = 22
# Length of each feature = 13

# %%
# Plot the features
features_mfcc = features_mfcc.T
plt.matshow(features_mfcc)
plt.title('MFCC')
# Out:
# Text(0.5, 1.0, 'MFCC')

# %%
# Extract the Filter Bank features
features_fb = logfbank(signal, sampling_freq)

# Print the parameters for Filter Bank
print('\nFilter bank:\nNumber of windows =', features_fb.shape[0])
print('Length of each feature =', features_fb.shape[1])
# Out:
# WARNING:root:frame length (1103) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# Filter bank:
# Number of windows = 22
# Length of each feature = 26

# %%
# Plot the features
features_fb = features_fb.T
plt.matshow(features_fb)
plt.title('Filter bank')

plt.show()

# %% [markdown]
# ## Recognizing spoken words

# %% [markdown]
# - Speech recognition systems take audio signals as input and recognize the words being spoken. Hidden Markov Models (HMMs) will be used for this task.
# - HMMs are great at analyzing sequential data. An audio signal is a time series signal, which is a manifestation of sequential data.
# - The assumption is that the outputs are being generated by the system going through a series of hidden states. Our goal is to find out what these hidden states are so that we can identify the words in our signal.

# %%
# !pip install hmmlearn
# Out:
# Collecting hmmlearn
#   Downloading hmmlearn-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.10/dist-packages (from hmmlearn) (1.26.4)
# Requirement already satisfied: scikit-learn!=0.22.0,>=0.16 in /usr/local/lib/python3.10/dist-packages (from hmmlearn) (1.5.2)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.10/dist-packages (from hmmlearn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (3.5.0)
# Downloading hmmlearn-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.6/164.6 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: hmmlearn
# Successfully installed hmmlearn-0.3.3

# %%
# !pip3 install hmmlearn
import os
import argparse
import warnings

from hmmlearn import hmm
from python_speech_features import mfcc

# %%
# # Define a function to parse the input arguments
# def build_arg_parser():
#   parser = argparse.ArgumentParser(description='Trains the HMM-based speech recognition')
#   parser.add_argument("--input-folder", dest="input_folder", required=True, help="Input
#   return parser

# %%
# Define a class to train the HMM
class ModelHMM(object):
    def __init__(self, num_components=4, num_iter=1000):
        self.n_components = num_components
        self.n_iter = num_iter

        self.cov_type = 'diag'
        self.model_name = 'GaussianHMM'

        self.models = []

        self.model = hmm.GaussianHMM(n_components=self.n_components,
                covariance_type=self.cov_type, n_iter=self.n_iter)

    # 'training_data' is a 2D numpy array where each row is 13-dimensional
    def train(self, training_data):
        np.seterr(all='ignore')
        cur_model = self.model.fit(training_data)
        self.models.append(cur_model)

    # Run the HMM model for inference on input data
    def compute_score(self, input_data):
        return self.model.score(input_data)

# %%
# Define a function to build a model for each word
def build_models(input_folder):
    # Initialize the variable to store all the models
    speech_models = []

    # Parse the input directory
    for dirname in os.listdir(input_folder):
        # Get the name of the subfolder
        subfolder = os.path.join(input_folder, dirname)

        if not os.path.isdir(subfolder):
            continue

        # Extract the label
        label = subfolder[subfolder.rfind('/') + 1:]

        # Initialize the variables
        X = np.array([])

        # Create a list of files to be used for training
        # We will leave one file per folder for testing
        training_files = [x for x in os.listdir(subfolder) if x.endswith('.wav')][:-1]

        # Iterate through the training files and build the models
        for filename in training_files:
            # Extract the current filepath
            filepath = os.path.join(subfolder, filename)

            # Read the audio signal from the input file
            sampling_freq, signal = wavfile.read(filepath)

            # Extract the MFCC features
            with warnings.catch_warnings():
                warnings.simplefilter('ignore')
                features_mfcc = mfcc(signal, sampling_freq)

            # Append to the variable X
            if len(X) == 0:
                X = features_mfcc
            else:
                X = np.append(X, features_mfcc, axis=0)

        # Create the HMM model
        model = ModelHMM()

        # Train the HMM
        model.train(X)

        # Save the model for the current word
        speech_models.append((model, label))

        # Reset the variable
        model = None

    return speech_models

# %%
# Define a function to run tests on input files
def run_tests(test_files):
    # Classify input data
    for test_file in test_files:
        # Read input file
        sampling_freq, signal = wavfile.read(test_file)

        # Extract MFCC features
        with warnings.catch_warnings():
            warnings.simplefilter('ignore')
            features_mfcc = mfcc(signal, sampling_freq)

        # Define variables
        max_score = -float('inf')
        output_label = None

        # Run the current feature vector through all the HMM
        # models and pick the one with the highest score
        for item in speech_models:
            model, label = item
            score = model.compute_score(features_mfcc)
            if score > max_score:
                max_score = score
                predicted_label = label

        # Print the predicted output
        start_index = test_file.find('/') + 1
        end_index = test_file.rfind('/')
        original_label = test_file[start_index:end_index]
        print('\nOriginal: ', original_label)
        print('Predicted:', predicted_label)

# %%
# Upload the data folder containing folders with fruit names to your google drive

# I experienced issues approving the necessary access for MyDrive to make the
# original code work.

# So I've commented out the code below to mount my Google drive and added a
# workaround in the next 2 cells.  First, I unzipped the speech_data.zip file
# which I had uploaded to the content folder.  Then I modified the input folder
# designation in the next step to reflect the appropriate path for the input
# folder.

# original cell code commented out:
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# I uploaded the speech_data.zip file to content folder and unzip it
# in this cell

# !unzip /content/speech_data.zip -d /content/
# Out:
# Archive:  /content/speech_data.zip
#    creating: /content/speech_data/
#   inflating: /content/__MACOSX/._speech_data
#   inflating: /content/speech_data/random_sound.wav
#   inflating: /content/__MACOSX/speech_data/._random_sound.wav
#   inflating: /content/speech_data/.DS_Store
#   inflating: /content/speech_data/tone_mapping.json
#   inflating: /content/__MACOSX/speech_data/._tone_mapping.json
#   inflating: /content/speech_data/spoken_word.wav
#   inflating: /content/__MACOSX/speech_data/._spoken_word.wav
#    creating: /content/speech_data/data/
#    creating: /content/speech_data/data/apple/
#   inflating: /content/__MACOSX/speech_data/data/._apple
#    creating: /content/speech_data/data/kiwi/
#   inflating: /content/__MACOSX/speech_data/data/._kiwi
#   inflating: /content/speech_data/data/README.md
#    creating: /content/speech_data/data/lime/
#   inflating: /content/__MACOSX/speech_data/data/._lime
#    creating: /content/speech_data/data/banana/
#   inflating: /content/__MACOSX/speech_data/data/._banana
#    creating: /content/speech_data/data/pineapple/
#   inflating: /content/__MACOSX/speech_data/data/._pineapple
#    creating: /content/speech_data/data/orange/
#   inflating: /content/__MACOSX/speech_data/data/._orange
#    creating: /content/speech_data/data/peach/
#   inflating: /content/__MACOSX/speech_data/data/._peach
#   inflating: /content/speech_data/data/apple/apple07.wav
#   inflating: /content/speech_data/data/apple/apple13.wav
#   inflating: /content/speech_data/data/apple/apple12.wav
#   inflating: /content/speech_data/data/apple/apple06.wav
#   inflating: /content/speech_data/data/apple/apple10.wav
#   inflating: /content/speech_data/data/apple/apple04.wav
#   inflating: /content/speech_data/data/apple/apple05.wav
#   inflating: /content/speech_data/data/apple/apple11.wav
#   inflating: /content/speech_data/data/apple/apple15.wav
#   inflating: /content/speech_data/data/apple/apple01.wav
#   inflating: /content/speech_data/data/apple/apple14.wav
#   inflating: /content/speech_data/data/apple/apple02.wav
#   inflating: /content/speech_data/data/apple/apple03.wav
#   inflating: /content/speech_data/data/apple/README.md
#   inflating: /content/speech_data/data/apple/apple08.wav
#   inflating: /content/speech_data/data/apple/apple09.wav
#   inflating: /content/speech_data/data/kiwi/kiwi08.wav
#   inflating: /content/speech_data/data/kiwi/kiwi09.wav
#   inflating: /content/speech_data/data/kiwi/README.md
#   inflating: /content/speech_data/data/kiwi/kiwi01.wav
#   inflating: /content/speech_data/data/kiwi/kiwi15.wav
#   inflating: /content/speech_data/data/kiwi/kiwi14.wav
#   inflating: /content/speech_data/data/kiwi/kiwi02.wav
#   inflating: /content/speech_data/data/kiwi/kiwi03.wav
#   inflating: /content/speech_data/data/kiwi/kiwi13.wav
#   inflating: /content/speech_data/data/kiwi/kiwi07.wav
#   inflating: /content/speech_data/data/kiwi/kiwi06.wav
#   inflating: /content/speech_data/data/kiwi/kiwi12.wav
#   inflating: /content/speech_data/data/kiwi/kiwi04.wav
#   inflating: /content/speech_data/data/kiwi/kiwi10.wav
#   inflating: /content/speech_data/data/kiwi/kiwi11.wav
#   inflating: /content/speech_data/data/kiwi/kiwi05.wav
#   inflating: /content/speech_data/data/lime/lime07.wav
#   inflating: /content/speech_data/data/lime/lime13.wav
#   inflating: /content/speech_data/data/lime/lime12.wav
#   inflating: /content/speech_data/data/lime/lime06.wav
#   inflating: /content/speech_data/data/lime/lime10.wav
#   inflating: /content/speech_data/data/lime/lime04.wav
#   inflating: /content/speech_data/data/lime/lime05.wav
#   inflating: /content/speech_data/data/lime/lime11.wav
#   inflating: /content/speech_data/data/lime/lime15.wav
#   inflating: /content/speech_data/data/lime/lime01.wav
#   inflating: /content/speech_data/data/lime/lime14.wav
#   inflating: /content/speech_data/data/lime/lime02.wav
#   inflating: /content/speech_data/data/lime/lime03.wav
#   inflating: /content/speech_data/data/lime/README.md
#   inflating: /content/speech_data/data/lime/lime08.wav
#   inflating: /content/speech_data/data/lime/lime09.wav
#   inflating: /content/speech_data/data/banana/banana03.wav
#   inflating: /content/speech_data/data/banana/banana02.wav
#   inflating: /content/speech_data/data/banana/banana14.wav
#   inflating: /content/speech_data/data/banana/banana01.wav
#   inflating: /content/speech_data/data/banana/banana15.wav
#   inflating: /content/speech_data/data/banana/banana11.wav
#   inflating: /content/speech_data/data/banana/banana05.wav
#   inflating: /content/speech_data/data/banana/banana04.wav
#   inflating: /content/speech_data/data/banana/banana10.wav
#   inflating: /content/speech_data/data/banana/banana06.wav
#   inflating: /content/speech_data/data/banana/banana12.wav
#   inflating: /content/speech_data/data/banana/banana13.wav
#   inflating: /content/speech_data/data/banana/banana07.wav
#   inflating: /content/speech_data/data/banana/README.md
#   inflating: /content/speech_data/data/banana/banana09.wav
#   inflating: /content/speech_data/data/banana/banana08.wav
#   inflating: /content/speech_data/data/pineapple/pineapple08.wav
#   inflating: /content/speech_data/data/pineapple/pineapple09.wav
#   inflating: /content/speech_data/data/pineapple/README.md
#   inflating: /content/speech_data/data/pineapple/pineapple02.wav
#   inflating: /content/speech_data/data/pineapple/pineapple03.wav
#   inflating: /content/speech_data/data/pineapple/pineapple01.wav
#   inflating: /content/speech_data/data/pineapple/pineapple15.wav
#   inflating: /content/speech_data/data/pineapple/pineapple14.wav
#   inflating: /content/speech_data/data/pineapple/pineapple04.wav
#   inflating: /content/speech_data/data/pineapple/pineapple10.wav
#   inflating: /content/speech_data/data/pineapple/pineapple11.wav
#   inflating: /content/speech_data/data/pineapple/pineapple05.wav
#   inflating: /content/speech_data/data/pineapple/pineapple13.wav
#   inflating: /content/speech_data/data/pineapple/pineapple07.wav
#   inflating: /content/speech_data/data/pineapple/pineapple06.wav
#   inflating: /content/speech_data/data/pineapple/pineapple12.wav
#   inflating: /content/speech_data/data/orange/orange09.wav
#   inflating: /content/speech_data/data/orange/orange08.wav
#   inflating: /content/speech_data/data/orange/orange03.wav
#   inflating: /content/speech_data/data/orange/README.md
#   inflating: /content/speech_data/data/orange/orange02.wav
#   inflating: /content/speech_data/data/orange/orange14.wav
#   inflating: /content/speech_data/data/orange/orange01.wav
#   inflating: /content/speech_data/data/orange/orange15.wav
#   inflating: /content/speech_data/data/orange/orange11.wav
#   inflating: /content/speech_data/data/orange/orange05.wav
#   inflating: /content/speech_data/data/orange/orange04.wav
#   inflating: /content/speech_data/data/orange/orange10.wav
#   inflating: /content/speech_data/data/orange/orange06.wav
#   inflating: /content/speech_data/data/orange/orange12.wav
#   inflating: /content/speech_data/data/orange/orange13.wav
#   inflating: /content/speech_data/data/orange/orange07.wav
#   inflating: /content/speech_data/data/peach/peach12.wav
#   inflating: /content/speech_data/data/peach/peach06.wav
#   inflating: /content/speech_data/data/peach/peach07.wav
#   inflating: /content/speech_data/data/peach/peach13.wav
#   inflating: /content/speech_data/data/peach/peach05.wav
#   inflating: /content/speech_data/data/peach/peach11.wav
#   inflating: /content/speech_data/data/peach/peach10.wav
#   inflating: /content/speech_data/data/peach/peach04.wav
#   inflating: /content/speech_data/data/peach/peach14.wav
#   inflating: /content/speech_data/data/peach/peach15.wav
#   inflating: /content/speech_data/data/peach/peach01.wav
#   inflating: /content/speech_data/data/peach/peach03.wav
#   inflating: /content/speech_data/data/peach/peach02.wav
#   inflating: /content/speech_data/data/peach/README.md
#   inflating: /content/speech_data/data/peach/peach09.wav
#   inflating: /content/speech_data/data/peach/peach08.wav

# %%
if __name__=='__main__':
    # args = build_arg_parser().parse_args()
    # input_folder = '/content/drive/MyDrive/data' replaced with:
    input_folder = '/content/speech_data/data'
    #args.input_folder

    # Build an HMM model for each word
    speech_models = build_models(input_folder)

    # Test files -- the 15th file in each subfolder
    test_files = []
    for root, dirs, files in os.walk(input_folder):
        for filename in (x for x in files if '15' in x):
            filepath = os.path.join(root, filename)
            test_files.append(filepath)

    run_tests(test_files)
# Out:
# Original:  content/speech_data/data/peach
# Predicted: peach
#
# Original:  content/speech_data/data/orange
# Predicted: orange
#
# Original:  content/speech_data/data/lime
# Predicted: lime
#
# Original:  content/speech_data/data/pineapple
# Predicted: pineapple
#
# Original:  content/speech_data/data/apple
# Predicted: apple
#
# Original:  content/speech_data/data/banana
# Predicted: banana
#
# Original:  content/speech_data/data/kiwi
# Predicted: kiwi
